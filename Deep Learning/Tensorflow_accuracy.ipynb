# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivang-Quantum/QuantaPytha/blob/Tutort/Deep%20Learning/Tensorflow_accuracy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import tensorflow as tf

# %%
pd.read_csv('/content/sample_data/diabetes.csv')
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# Defining the Data
df=pd.read_csv('/content/sample_data/diabetes.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# Splitting the data
x_train=df[['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']].values
y_train=df.Outcome.values

#df.Outcome.values

# %%
x_train
# Out:
# array([[6.000e+00, 1.480e+02, 7.200e+01, 3.500e+01, 0.000e+00, 3.360e+01,
#         6.270e-01, 5.000e+01, 1.000e+00],
#        [1.000e+00, 8.500e+01, 6.600e+01, 2.900e+01, 0.000e+00, 2.660e+01,
#         3.510e-01, 3.100e+01, 0.000e+00],
#        [8.000e+00, 1.830e+02, 6.400e+01, 0.000e+00, 0.000e+00, 2.330e+01,
#         6.720e-01, 3.200e+01, 1.000e+00],
#        [1.000e+00, 8.900e+01, 6.600e+01, 2.300e+01, 9.400e+01, 2.810e+01,
#         1.670e-01, 2.100e+01, 0.000e+00],
#        [0.000e+00, 1.370e+02, 4.000e+01, 3.500e+01, 1.680e+02, 4.310e+01,
#         2.288e+00, 3.300e+01, 1.000e+00],
#        [5.000e+00, 1.160e+02, 7.400e+01, 0.000e+00, 0.000e+00, 2.560e+01,
#         2.010e-01, 3.000e+01, 0.000e+00],
#        [3.000e+00, 7.800e+01, 5.000e+01, 3.200e+01, 8.800e+01, 3.100e+01,
#         2.480e-01, 2.600e+01, 1.000e+00]])

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-cfcea75e76a5> in <cell line: 1>()
# ----> 1 x_train.info()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'info'

# %%
# Build Architecture

model=tf.keras.Sequential()

#hidden Layer 1
#model.add(tf.keras.layers.Dense(10))
model.add(tf.keras.layers.Dense(10,activation='relu',kernel_initializer='he_uniform'))

#hidden Layer 2
#model.add(tf.keras.layers.Dense(10))
model.add(tf.keras.layers.Dense(10,activation='sigmoid'))

#Output Layer [The layer that is at the end]
model.add(tf.keras.layers.Dense(1))

# %%
model.compile(optimizer='sgd',loss='mean_squared_error',metrics=['Accuracy'])

# %%
model.fit(x_train,y_train,epochs=20)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2267 - Accuracy: 0.6510
# Epoch 2/20
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2267 - Accuracy: 0.6510
# Epoch 3/20
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2266 - Accuracy: 0.6510
# Epoch 4/20
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2262 - Accuracy: 0.6510
# Epoch 5/20
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2258 - Accuracy: 0.6510
# Epoch 6/20
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2256 - Accuracy: 0.6510
# Epoch 7/20
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2252 - Accuracy: 0.6510
# Epoch 8/20
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2249 - Accuracy: 0.6510
# Epoch 9/20
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2247 - Accuracy: 0.6510
# Epoch 10/20
# ...

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (32, 10)                  90
#
#  dense_1 (Dense)             (32, 10)                  110
#
#  dense_2 (Dense)             (32, 1)                   11
#
# ...
# Total params: 211 (844.00 Byte)
# Trainable params: 211 (844.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
