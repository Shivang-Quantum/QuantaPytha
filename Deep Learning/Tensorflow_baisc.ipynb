# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.15.0'

# %%
import pandas as pd

# %%
import numpy as np

# %%
# Create a small data set

dataset={
    'feature 1':np.random.rand(100),
    'feature 2':np.random.rand(100),
    'target':3 * np.random.rand(100) + 2 * np.random.rand(100) + 1 + 0.1 * np.random.randn(100)
    }

# %%
df=pd.DataFrame(dataset)

# %%
df
# Out:
#     feature 1  feature 2    target
# 0    0.029372   0.689797  3.888102
# 1    0.925930   0.601070  2.827275
# 2    0.375974   0.975420  4.152315
# 3    0.136031   0.120682  4.936511
# 4    0.643301   0.269331  4.155339
# ..        ...        ...       ...
# 95   0.778071   0.633868  2.731271
# 96   0.751428   0.131287  3.951742
# 97   0.434191   0.558138  2.315424
# 98   0.278374   0.484137  4.427269
# 99   0.927291   0.333362  2.262793
#
# [100 rows x 3 columns]

# %%
# splitting the data

x_train=df[['feature 1','feature 2']].values
y_train=df.target.values

# %%
# Build Architecture

model=tf.keras.Sequential()

#hidden Layer 1
model.add(tf.keras.layers.Dense(10))

#hidden Layer 2
model.add(tf.keras.layers.Dense(10))

#Output Layer [The layer that is at the end]
model.add(tf.keras.layers.Dense(1))

# %%
model.compile(optimizer='sgd',loss='mean_squared_error')

# %%
model.fit(x_train,y_train,epochs=15)
# Out:
# Epoch 1/15
# 4/4 [==============================] - 2s 15ms/step - loss: 8.3163
# Epoch 2/15
# 4/4 [==============================] - 0s 4ms/step - loss: 3.6691
# Epoch 3/15
# 4/4 [==============================] - 0s 3ms/step - loss: 2.0202
# Epoch 4/15
# 4/4 [==============================] - 0s 4ms/step - loss: 1.5886
# Epoch 5/15
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5881
# Epoch 6/15
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5192
# Epoch 7/15
# 4/4 [==============================] - 0s 4ms/step - loss: 1.4943
# Epoch 8/15
# 4/4 [==============================] - 0s 4ms/step - loss: 1.5095
# Epoch 9/15
# 4/4 [==============================] - 0s 4ms/step - loss: 1.4577
# Epoch 10/15
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5106
# Epoch 11/15
# 4/4 [==============================] - 0s 3ms/step - loss: 1.4254
# Epoch 12/15
# 4/4 [==============================] - 0s 4ms/step - loss: 1.4743
# Epoch 13/15
# 4/4 [==============================] - 0s 4ms/step - loss: 1.5002
# Epoch 14/15
# 4/4 [==============================] - 0s 4ms/step - loss: 1.3758
# Epoch 15/15
# 4/4 [==============================] - 0s 3ms/step - loss: 1.4583
